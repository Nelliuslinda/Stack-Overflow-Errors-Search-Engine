# %%
# !pip install datasets -q
#TFIDF, Word Embeddings, Bag of Words
# !pip install sentence_transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.1/163.1 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 61.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 47.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 66.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.2 MB/s eta 0:00:00

# %%
from datasets import load_dataset
dataset = load_dataset("pacovaldez/stackoverflow-questions", split='validation')
dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/19 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/19 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/41.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.6M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.7M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.7M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.7M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/132M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/132M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/133M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.6M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.7M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.7M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.6M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['title', 'body', 'label'],
#     num_rows: 785098
# })

# %%
texts = dataset['title']
print(len(texts))
# Out:
# 785098

# %%
#Print first 10
texts[:10]
# Out:
# ['How to dynamically instntiate a class?',
#  'update value on button on:click event vue js',
#  'Setinterval for div in jquery',
#  'Phonegap twitter plugin for ios4',
#  'Looping thru 2 set of data in puppet - optimalization',
#  'Is this Dicelose correct for multiclass',
#  'How to update UIProgressview in Tableviewcell?',
#  'Add user in aws postgreSQL DB when user added to AD using lambda',
#  'print char pointer value in c',
#  'Antd Custom Radio Button Mega Option Form Component']

# %% [markdown]
# ###Feature Extraction

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
sample = texts[5]
sample_enc = model.encode(sample)
print('Length of enc', len(sample_enc))
# Out:
# Length of enc 384

# %%
print(sample_enc)
# Out:
# [-0.3423843   0.37420204 -0.45176965 -0.925032   -0.46697903 -0.08909266
#   0.1502915  -0.2362559   0.23827972  0.09115169  0.22503485 -0.09578223
#  -0.32164323  0.49602643  0.41214892  0.09596945 -0.42052773  0.087498
#  -0.55316454  0.02788622  0.5204729  -0.21576323  0.36587763 -0.23482281
#   0.02392544  0.24140692 -0.5039559  -0.09328669  0.4293289   0.37273744
#   0.31094292  0.98085904 -0.1090482  -0.11080189 -0.44970685  0.23855272
#  -0.5514319   0.41394424 -0.03059185  0.5504756  -0.10439875  0.1313458
#  -0.07704359  0.22947861 -0.28906968  0.20369767 -0.7639803   0.26500317
#   0.16125579 -0.10006391  0.17438012 -0.28656763 -0.72924227  0.20886268
#   0.29429895 -0.15818836 -0.12105019 -0.31504333 -0.13363777  0.09422
#  -0.04318023 -0.08944136 -0.01707572  0.39439765  0.39025792 -0.3772578
#  -0.03140264  0.23960166 -0.06019128  0.13326685 -0.21193172 -0.32110795
#  -0.14727896 -0.02377558  0.3052235   0.08653912 -0.07893209 -0.1331411
#   0.6617563  -0.01746196 -0.06526871 -0.38154948 -0.5643498  -0.07920225
#   0.07829273 -0.18995053 -0.07748138 -0.07256322  0.18561903  0.26987663
#  -0.01378985 -0.30655143 -0.59818333  0.48963884 -0.45465612  0.58828413
#   0.2596858  -0.15110847 -0.298649    0.19896895 -0.08403483 -0.24326286
#  -0.17419282  0.241545    0.19001895 -0.51980567 -0.24640733 -0.6167037
#   0.27209947 -0.25036192 -0.16837995 -0.15721914  0.09952361 -0.12653185
#  -0.7876019  -0.02508996 -0.2521838   0.16489302  0.19893485  0.04574392
#   0.21497688 -0.24487029  0.20196281 -0.19918321  0.42822883  0.12898012
#  -0.09528527  0.15038227 -0.253343   -0.16360416  0.41486514  0.06951538
#   0.34401187  0.05145486  0.00221147  0.06182592 -0.39649132 -0.08652855
#   0.16544133  0.02027029  0.07280305  0.5973466  -0.06707119 -0.14578085
#  -0.03367138 -0.34351876  0.20723881 -0.02463027  0.48437798 -0.00832409
#   0.13568515 -0.26500148 -0.12992695  0.7047072   0.68526864  0.06240776
#  -0.03895759 -0.49655807 -0.0936598   0.28430393 -0.11837299  0.6507522
#   0.1952198  -0.21161084 -0.21257477  0.04826082 -0.20905592 -0.06813902
#  -0.2632523   0.08353603 -0.18857613 -0.59851605  0.31724766  0.4343126 ]

# %%
embeddings = model.encode(texts[:700])

# %% [markdown]
# ###Clustering

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters = 5, random_state = 42)
km.fit(embeddings)

cluster_labels = km.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ###Search

# %%
from sklearn.metrics.pairwise import cosine_similarity as cs

def search(query, texts, embeddings):
  q_emb = model.encode([query])[0]
  sim_scores = cs([q_emb], embeddings)[0]
  results = [(texts[i], sim_scores[i]) for i in range (len(texts))]
  results.sort(key=lambda x: x[1], reverse = True)
  return results

# %%
query = 'Module not found'
s_results = search(query, texts[:700], embeddings)

# %%
from tqdm.auto import tqdm

scores = []
titles = []

for i in range(len(tqdm(s_results))):
  scores.append(s_results[i][1])
  titles.append(s_results[i][0])
# Out:
#   0%|          | 0/700 [00:00<?, ?it/s]

# %%
import pandas as pd

df = pd.DataFrame(
    {
        "Titles": titles,
        "Sim": scores
    }
)

df = df.sort_values('Sim', ascending = False)
df.head(10)
# Out:
#                                               Titles       Sim
# 0               ImportError: No module named 'parse'  0.663350
# 1  Module build failed (from ./node_modules/babel...  0.549500
# 2  eslint + typescript + path in tsconfig: ESLint...  0.467615
# 3  How do I include a Perl module that's in a dif...  0.453819
# 4  Error whilst installing magento extension- pac...  0.438410
# 5                Entity Framework Cast not supported  0.410880
# 6  ASP.NET framework MVC5 empty project NuGet Pac...  0.408930
# 7                 Failing to compile vlc for android  0.388735
# 8            Problems While Trying To Compile MacVim  0.387978
# 9  Eclipse Java Missing required source folder: '...  0.369784

# %% [markdown]
# ###Deployment

# %%
def deploy(error_text):
  s_results = search(error_text, texts[:700], embeddings)
  scores = []
  titles = []

  for i in range(len(tqdm(s_results))):
    scores.append(s_results[i][1])
    titles.append(s_results[i][0])

  df = pd.DataFrame({"Titles":titles, "Sim": scores})
  df = df.sort_values('Sim', ascending = False)
  print(df.head(10))

# %%
x = input("Enter an error description.....")
deploy(str(x))
# Out:
# Enter an error description.....Name Error
#   0%|          | 0/700 [00:00<?, ?it/s]
#                                               Titles       Sim
# 0         + name + not working in Python 3.8.2 shell  0.573756
# 1  Why is dotPeek still able to figure out origin...  0.420441
# 2  What is the error in the code ? I want to call...  0.410352
# 3          can someone tell me what this error mean?  0.400345
# 4  How to change column name of database to upper...  0.391787
# 5                  PHP Special Character Parse Error  0.381270
# 6                           plupload filename change  0.359437
# 7                Entity Framework Cast not supported  0.352910
# 8  Dynamic loading of classes can't address names...  0.343490
# 9  How do I add ASP.NET Identity tables in my dat...  0.334151
